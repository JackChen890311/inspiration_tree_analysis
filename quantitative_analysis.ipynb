# %%
from utils.ScoreKeeper import load_exp, load_score_keepers
from utils.score_utils import *
from utils.exp_utils import list_exp_names, list_concept_names

# %%
dataset_name = "v2_sub"
exp_names = list_exp_names(dataset_name)
cpt_names = list_concept_names(dataset_name)
# Out:
# ===== Experiment names for v2_sub: =====
# 20250330_instree_origin
# 20250331_attn_mask
# 20250401_attn_mask_no_otsu
# 20250402_attn_mask_hybrid_loss(wrong)
# 20250404_hybrid_loss_correct
# 20250405_attn_mask_union_sampling
# 20250407_attn_mask_union_sampling_0.9
# 20250408_0407_no_otsu
# 20250409_0408_rand_0.95
# 20250410_0408_hybrid
# 20250411_all_res
# 20250412_real_all_res
# ===== Total experiments: 12 =====
# ===== Concept names for v2_sub: =====
# buddha
# canada_bear
# cat_statue
# colorful_teapot
# decoritems_woodenpot
# elephant
# green_dall
# mug_buildings
# mug_skulls
# physics_mug
# plushie_tortoise
# red_teapot
# round_bird
# ===== Total concepts: 13 =====

# %%
exp_sk_lists = []
analysis_names = [
    "20250330_instree_origin", 
    "20250410_0408_hybrid",
    "20250411_all_res",
    "20250412_real_all_res",
]
# analysis_names = exp_names
for exp_name in analysis_names:
    exp_sk_lists.append(load_exp("v2_sub", exp_name))
    print(f"Loaded {exp_name} with {len(exp_sk_lists[-1])} score keepers.")

# %%
idx = -1
plot_one_exp(exp_sk_lists[idx], types=['final'], title=analysis_names[idx])

# %%
plot_exp_comparison(exp_sk_lists,
                    analysis_names, 
                    types=['final'])

# %%
for exp, name in zip(exp_sk_lists, analysis_names):
    summary_exp(exp, name)
# Out:
# Summary for 20250330_instree_origin:
# dict_keys(['green_dall', 'mug_buildings', 'buddha', 'canada_bear', 'decoritems_woodenpot', 'mug_skulls', 'plushie_tortoise', 'cat_statue', 'red_teapot', 'round_bird', 'colorful_teapot', 'elephant', 'physics_mug'])
# 1.5654143140866206
# 0.032329799711543455
# Summary for 20250410_0408_hybrid:
# dict_keys(['green_dall', 'mug_buildings', 'buddha', 'canada_bear', 'decoritems_woodenpot', 'mug_skulls', 'plushie_tortoise', 'cat_statue', 'red_teapot', 'round_bird', 'colorful_teapot', 'elephant', 'physics_mug'])
# 1.568148755110227
# 0.021731252039727724
# Summary for 20250411_all_res:
# dict_keys(['green_dall', 'mug_buildings', 'buddha', 'canada_bear', 'decoritems_woodenpot', 'mug_skulls', 'plushie_tortoise', 'cat_statue', 'red_teapot', 'round_bird', 'colorful_teapot', 'elephant', 'physics_mug'])
# 1.5848006055905268
# 0.021448605414882565
# Summary for 20250412_real_all_res:
# dict_keys(['green_dall', 'mug_buildings', 'buddha', 'canada_bear', 'decoritems_woodenpot', 'mug_skulls', 'plushie_tortoise', 'cat_statue', 'red_teapot', 'round_bird', 'colorful_teapot', 'elephant', 'physics_mug'])
# 1.5819625831567323
# 0.02100302320626812

# %%
get_concept_score(exp_sk_lists, 'physics_mug')
# Out:
# Concept: physics_mug
# Base Path: experiments/v2_sub/20250330_instree_origin/outputs
# Node: v0
# Seed: 111
# Consistency Score (Final): [1.4971739053726196, 1.6203277111053467, 1.4749001860618591, 1.5089688301086426, 1.52702397108078, 1.39095139503479, 1.5816377401351929, 1.511361300945282, 1.6579057276248932, 1.5179695188999176]
# Concept: physics_mug
# Base Path: experiments/v2_sub/20250410_0408_hybrid/outputs
# Node: v0
# Seed: 111
# Consistency Score (Final): [1.5421001315116882, 1.5039460062980652, 1.4519845843315125, 1.4009791612625122, 1.3667922019958496, 1.2032382190227509, 1.1860322952270508, 1.2856046259403229, 1.217510998249054, 1.2175678610801697]
# Concept: physics_mug
# Base Path: experiments/v2_sub/20250411_all_res/outputs
# Node: v0
# Seed: 111
# Consistency Score (Final): [1.5421001315116882, 1.4435539245605469, 1.5216646790504456, 1.523845136165619, 1.3795511722564697, 1.3865913152694702, 1.3012036383152008, 1.1777153313159943, 1.1561522781848907, 1.2533800899982452]

# %%
plot_concept_comparison(exp_sk_lists[:-1], analysis_names[:-1], field='final')

# %%
sk_list = load_score_keepers("/home/jack/Code/Research/instree_main/outputs", "v0")
sk_list
# Out:
# {'green_dall': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2911f760>,
#  'mug_buildings': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29007af0>,
#  'buddha': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29005600>,
#  'canada_bear': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2911e740>,
#  'decoritems_woodenpot': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2911f730>,
#  'mug_skulls': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29007b50>,
#  'plushie_tortoise': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29171480>,
#  'cat_statue': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2904be20>,
#  'red_teapot': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29171540>,
#  'round_bird': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d290b7880>,
#  'colorful_teapot': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2911fa90>,
#  'elephant': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d2aae3a60>,
#  'physics_mug': <utils.ScoreKeeper.ScoreKeeper at 0x7f1d29171120>}
